# %% [markdown]
# <div style="
#     background-color: #7BAFD4;
#     border-radius: 18px;
#     padding: 22px 26px;
#     display: flex;
#     align-items: center;
#     gap: 24px;
#     margin-bottom: 18px;
# ">
#     <img src="592_avatar_lr.png" alt="GEOG 592"
#         style="width:110px;height:110px;border-radius:22px;">
#     <div>
#         <div style="
#             font-family: Impact, 'Arial Black', Arial, sans-serif;
#             font-size: 42px;
#             font-weight: 900;
#             letter-spacing: 2px;
#             line-height: 1;
#             color: white;
#         ">GEOG 592</div>
#         <div style="
#             font-family: Arial, Helvetica, sans-serif;
#             font-size: 22px;
#             font-weight: 700;
#             color: #13294B;
#             margin-top: 8px;
#         ">GIS Programming</div>
#         <div style="
#             font-family: Arial, Helvetica, sans-serif;
#             font-size: 16px;
#             color: #13294B;
#             margin-top: 6px;
#         ">Homework 5: Working with Pandas</div>
#     </div>
# </div>

# %%
import pandas as pd

# %% [markdown]
# 1. In the code below, identify the object and the method.
#              df.head()
#
# The method is the .head() method, as methods are indicated by the () that indicate the methods need for a parameter. Therefore, the object is the dataframe that the method is being performed on, which is called df.

# %% [markdown]
# 2. Is `df.shape` an attribute or a method?
#
# .shape is an attribute, as it has no parenthesis and does not require any parameters for it to run.

# %% [markdown]
# 3. If `df.shape` returns `(75, 8)`, explain what both numbers mean.
#
# The shape attribute returns the shape of the dataset, meaning that the df object has 75 rows and 8 columns.

# %% [markdown]
# 4. What type of pandas object is usually returned by `df["Data_Value"]`?
#
# df["Data_Value"] would return the panda series object, as it returns the entire column of the data_values in a series format.

# %% [markdown]
# 5. What type of pandas object is usually returned by `df[["County", "Data_Value"]]`?
#
# When more than one column of data is selected, the pandas will return a dataframe object.

# %%
parks = pd.DataFrame({"Park":["Oak","Pine","Maple","Cedar"], "Area":[12,25,18,40], "Visitors":[120,250,180,310]})

# %% [markdown]
# 6. Write the expression that selects only the `Visitors` column from the `parks` data frame.
#
# parks["Visitors"]

# %% [markdown]
# 7. Write the expression that selects only `Park` and `Visitors` from the `parks` data frame.
#
# parks[["Park", "Visitors"]]

# %% [markdown]
# 8. What does `parks.iloc[0]` return?
#
# The iloc method selects for rows and columns by integer positioning. Therefore, parks.iloc[0] would return ["Park" : "Oak", "Area": 12, "Visitors": 120]

# %% [markdown]
# 9. What rows are selected by `parks.iloc[1:4]`?
#
# The second through fourth rows would be selected (as python starts indexing at 0, so the first row would technically be the second by regular counting and ranges do not include the last value, so it would stop at 3, which is again technically the fourth row. )

# %% [markdown]
# 10. Write one expression that selects rows 2 through 4 by position and then keeps only `Park` and `Area`.
#
# parks.iloc[1:4][["Park", "Area"]]

# %% [markdown]
# 11. Write a Boolean filter that keeps only parks with `Area > 20`.
#
# parks["Area"] > 20

# %%
cleaned_parks = parks["Area"] > 20
print(cleaned_parks[cleaned_parks == True])
# Out:
# 1    True
# 3    True
# Name: Area, dtype: bool

# %% [markdown]
# 12. What rows would remain after that filter?
#
# Rows 1 and 3 are returned

# %% [markdown]
# 13. Create a new DataFrame named `large_parks` containing those rows and make it an independent copy.
#
# large_parks = parks[parks["Area"] > 20].copy()

# %% [markdown]
# 14. Why might `.copy()` be useful after filtering?
#
# You can modify the copy without having to worry about accidentally modifying the original csv file and producing warnings.

# %% [markdown]
# 15. Write one line that changes all three column names to `Name`, `Area_ha`, and `Annual_Visitors` using `df.columns = [...]`.
#
# parks.columns = ["Name", "Area_ha", "Annual_Visitors"]

# %% [markdown]
# 16. What problem occurs if the list assigned to `.columns` has only two names while the DataFrame has three columns?
#
# You get a ValueError as you cannot create a list to reassign names that is shorter than the existing list of column names.

# %%
values = pd.Series(["12.5", "18.0", "missing", "22.5"])
print(values)
# Out:
# 0       12.5
# 1       18.0
# 2    missing
# 3       22.5
# dtype: str

# %% [markdown]
# 17. Why might pandas store these values as strings rather than numbers?
#
# If there are any errors in the column (ie. mixed data, meaning there might be one instance of a string) pandas will default to all string values.

# %% [markdown]
# 18. Write code using `pd.to_numeric(..., errors="coerce")` to convert the Series.
#
# values = pd.to_numeric(values, errors = "coerce")

# %%
values = pd.to_numeric(values, errors = "coerce")
print(values)
# Out:
# 0    12.5
# 1    18.0
# 2     NaN
# 3    22.5
# dtype: float64

# %% [markdown]
# 19. What happens to the value `"missing"` when `errors="coerce"` is used?
#
# The value missing becomes NaN when using errors="coerce" as this allows the pd.to_numeric method to continue running even when encountering values that cannot be converted to numbers.

# %% [markdown]
# 20. What does `.isna().sum()` tell you?
#
# the .isna method iterates through a series and returns boolean values if the value is NaN. Therefore, the sum method calculates the total "TRUE" responses and gives a total number of NaN values found in the series.

# %% [markdown]
# 21. Explain the difference between `dropna()` and `fillna()`.
#
# .dropna is a method that fully removes all NaN values from the series, while .fillna replaces these missing values with another value (often 0).

# %% [markdown]
# 22. Write code that sorts `parks` from the highest to lowest number of visitors.
#
# print(parks.sort_values("Annual_Visitors", ascending = False))

# %%
print(parks.sort_values("Annual_Visitors", ascending = False))
# Out:
#     Name  Area_ha  Annual_Visitors
# 3  Cedar       40              310
# 1   Pine       25              250
# 2  Maple       18              180
# 0    Oak       12              120

# %% [markdown]
# 23. Write code to calculate the mean and median of `Visitors`.
#
# print(parks["Annual_Visitors"].mean())
# print(parks["Annual_Visitors"].median())

# %% [markdown]
# 24. In a strongly right-skewed distribution, which is usually larger: the mean or the median? Why?
#
# The mean is usually higher, as right-skewed distribution typically hints at larger outliers that pull the mean higher away from the median of the data.

# %% [markdown]
# 25. In a histogram, what does `bins=10` control?
#
# The bins are the total number of intervals used to divide the data into, so bins=10 is telling the program to divide all of the data into ten bins that are portrayed on the histogram.

# %% [markdown]
# 26. What is `ax` in `ax = df["Value"].plot(kind="hist")`?
#
# ax is a matplotlib object

# %% [markdown]
# 27. Write the Matplotlib commands that set a title, x-axis label, and y-axis label on `ax`.
#
# ax.set_title("")
# ax.set_xlabel("")
# ax.set_ylabel("")

# %% [markdown]
# 28. Explain the difference between equal interval and quantile classification.
#
# Equal interval creates intervals that are all the same width, while quantile creates intervals so that an equal number of data points fall within each interval.

# %% [markdown]
# 29. Suppose `values = [5, 12, 3, 20]`. Write a short Python loop that prints only values greater than 10. Then write the pandas-style Boolean condition you would use if the same values were in a Series called `s`.

# %%
values = [5, 12, 3, 20]

for value in values:
    if value > 10:
        print(value)


s = pd.DataFrame({"values":[5, 12, 3, 20]})

s_cleaned = s[s > 10]

s_cleaned.dropna(subset=["values"])
# Out:
# 12
# 20
#    values
# 1    12.0
# 3    20.0
